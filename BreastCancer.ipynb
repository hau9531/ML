# %% [markdown]
# # Breast Cancer

# %%
#Import libraries

import numpy as np #It is used for linear algebra
import pandas as pd #It is used for data processing
#Data visualisation libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read csv file that contains dataset
cancer = pd.read_csv('b_cancer.csv')

# %%
#To check the details of features, use info() function.
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
#To show first 5 rows, use head() function
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#To show last 5 rows, use tail() function
cancer.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
#Remove unwanted columns using drop() function
cancer = cancer.drop(columns = ['id','Unnamed: 32'])

# %%
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# compactness_se             569 non-null float64
# ...

# %% [markdown]
# ## Data Analysis

# %%
sns.countplot(cancer['diagnosis'])
#The plot displays the labels in the data i.e. B and M

# %%
#Divide features according to their category
mean_features = list(cancer.columns[1:11])
se_features = list(cancer.columns[11:21])
worst_features = list(cancer.columns[21:31])

# %%
corr = cancer[mean_features].corr() # .corr() is used to find corelation
plt.figure(figsize = (15,15))

sns.heatmap(corr, cbar=True, square=True, fmt='.2f', annot=True,
           xticklabels=mean_features, yticklabels=mean_features, cmap='coolwarm')

# %%
corr = cancer[se_features].corr()
plt.figure(figsize = (15,15))

sns.heatmap(corr, cbar=True, square=True, fmt='.2f', annot=True,
           xticklabels=se_features, yticklabels=se_features, cmap='coolwarm')

# %%
corr = cancer[worst_features].corr()
plt.figure(figsize = (15,15))

sns.heatmap(corr, cbar=True, square=True, fmt='.2f', annot=True,
           xticklabels=worst_features, yticklabels=worst_features, cmap='coolwarm')

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(cancer, test_size=0.25)

print("Training set shape:{}".format(train.shape))
print("Test set shape:{}".format(test.shape))
# Out:
# Training set shape:(426, 31)
# Test set shape:(143, 31)

# %%
prediction = ['radius_mean','texture_mean', 'compactness_mean', 'symmetry_mean', 'smoothness_mean']

# %%
x_train = train[prediction]
y_train = train.diagnosis

x_test = test[prediction]
y_test = test.diagnosis

# %% [markdown]
# # Model Implementation

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

model1 = RandomForestClassifier(random_state=0)
model1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
print("Accuracy of training set:{:.3f}".format(model1.score(x_train,y_train)))
print("Accuracy of test set:{:.3f}".format(model1.score(x_test,y_test)))
# Out:
# Accuracy of training set:0.998
# Accuracy of test set:0.930

# %%
from sklearn.metrics import classification_report

predicted = model1.predict(x_test)
report = classification_report(y_test, predicted)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.97      0.95        96
#            M       0.93      0.85      0.89        47
#
#    micro avg       0.93      0.93      0.93       143
#    macro avg       0.93      0.91      0.92       143
# weighted avg       0.93      0.93      0.93       143

# %%
from sklearn.metrics import confusion_matrix
predicted = model1.predict(x_test)
report = confusion_matrix(y_test, predicted)
print(report)
# Out:
# [[93  3]
#  [ 7 40]]

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model2 = LogisticRegression(random_state=0)
model2.fit(x_train,y_train)
# Out:
# C:\Users\mande\Anaconda2\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
print("Accuracy of training set:{:.3f}".format(model2.score(x_train,y_train)))
print("Accuracy of test set:{:.3f}".format(model2.score(x_test,y_test)))
# Out:
# Accuracy of training set:0.892
# Accuracy of test set:0.909

# %%
from sklearn.metrics import classification_report

predicted = model2.predict(x_test)
report = classification_report(y_test, predicted)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            B       0.90      0.98      0.94        96
#            M       0.95      0.77      0.85        47
#
#    micro avg       0.91      0.91      0.91       143
#    macro avg       0.92      0.87      0.89       143
# weighted avg       0.91      0.91      0.91       143

# %%
from sklearn.metrics import confusion_matrix
predicted = model2.predict(x_test)
report = confusion_matrix(y_test, predicted)
print(report)
# Out:
# [[94  2]
#  [11 36]]

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

model3 = KNeighborsClassifier()
model3.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
print("Accuracy of training set:{:.3f}".format(model3.score(x_train,y_train)))
print("Accuracy of test set:{:.3f}".format(model3.score(x_test,y_test)))
# Out:
# Accuracy of training set:0.908
# Accuracy of test set:0.902

# %%
from sklearn.metrics import classification_report

predicted = model3.predict(x_test)
report = classification_report(y_test, predicted)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            B       0.91      0.95      0.93        96
#            M       0.88      0.81      0.84        47
#
#    micro avg       0.90      0.90      0.90       143
#    macro avg       0.90      0.88      0.89       143
# weighted avg       0.90      0.90      0.90       143

# %%
from sklearn.metrics import confusion_matrix
predicted = model3.predict(x_test)
report = confusion_matrix(y_test, predicted)
print(report)
# Out:
# [[91  5]
#  [ 9 38]]

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model4 = DecisionTreeClassifier(random_state=0, min_samples_leaf=4, min_impurity_decrease=0.0)
model4.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=4, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
print("Accuracy of training set:{:.3f}".format(model4.score(x_train,y_train)))
print("Accuracy of test set:{:.3f}".format(model4.score(x_test,y_test)))
# Out:
# Accuracy of training set:0.972
# Accuracy of test set:0.909

# %%
from sklearn.metrics import classification_report

predicted = model4.predict(x_test)
report = classification_report(y_test, predicted)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.95      0.94        96
#            M       0.89      0.85      0.87        47
#
#    micro avg       0.92      0.92      0.92       143
#    macro avg       0.91      0.90      0.90       143
# weighted avg       0.92      0.92      0.92       143

# %%
from sklearn.metrics import confusion_matrix
predicted = model4.predict(x_test)
report = confusion_matrix(y_test, predicted)
print(report)
# Out:
# [[91  5]
#  [ 7 40]]

# %% [markdown]
# ### Neural Network

# %%
dataset=pd.read_csv("b_cancer.csv")

# %%
d = {'M':1,'B':0}
dataset = dataset.replace(d) #replace M/B with 0 or 1 for the neural network classification
dataset = dataset.drop(['Unnamed: 32'],axis=1) #remove column 32 - unknown purpose
dataset = dataset.drop(['id'],axis=1) #remove the id - not required for analysis

# %%
dataset_temp = dataset.drop(['diagnosis'],axis=1) #make a dataset with only our feature vectors
X = np.array(dataset_temp).T #create a Numpy array of feature vectors to be used in our neural network
Y = np.array(dataset['diagnosis']).T #create a Numpy array of diagnosis to be used in our neural network
Y = Y.reshape(1,569)

# %%
#Now, let's normalize our feature vector. We will divide the mean of each feature by the maximum
X_mean = np.mean(X,axis=1,keepdims=True) #Find the mean of each feature
X_max = np.max(X,axis=1,keepdims=True) #Find the maximum of each feature
X_normalized = (X-X_mean)/(X_max) #Normalizing the dataset by subtracting the mean and dividing by the max

# %%
#Now, let's split our dataset into two segments
# 1) Training set to train our neural network
# 2) A test set to test the accuracy of our neural network

#We'll take the first 380 samples for our training set
X_train = X_normalized[:,:380]
Y_train = Y[:,:380]

#We will take the remaining 189 for our test set
X_test = X_normalized[:,381:]
Y_test = Y[:,381:]

# %%
#We will now define our sigmoid function to be used in the output layer of our neural network (L3)
def sigmoid(z):
    s = 1/(1+np.exp(-z))
    return s

# %%
#We will now define our tanh(x) function to be used in hidden layers of our neural network (L1, L2)
#Note that the tanh(x) function allows better centering of data than the sigmoid function. This is why it will be used in our hidden layers.

def tanh(z):
    s = (np.exp(z) - np.exp(-z)) / (np.exp(z) + np.exp(-z))
    return s

# %%
#Now, let's define our forward propogation function.
def forward_prop(X,W1,W2,W3,b1,b2,b3):
    
    #First layer forward propogation
    Z1 = np.dot(W1,X)
    A1 = tanh(Z1 + b1)
    #Second layer forward propogation
    Z2 = np.dot(W2,A1)
    A2 = tanh(Z2 + b2)
    #Third layer forward propogation
    Z3 = np.dot(W3,A2)
    A3 = sigmoid(Z3 + b3) #A3 will produce our probability vector
    
    cache = {    
                  "Z1": Z1,
                  "A1": A1,
                  "Z2": Z2,
                  "A2": A2,
                  "Z3": Z3,
                  "A3": A3
            }
    return cache

# %%
#Now we will perform gradient descent for our neural network in the following steps:
#1) Start by randomly initializing our weight and intercept parameters
#2) Run forward propogation through our neural network
#3) Calculate the derivatives of our weights and intercept parameters via back propogation
#4) Refine our parameters using derivatives from (3)
#5) Reiterate 1 - 4 

def gradient_descent(iterations,X,Y,alpha):
    
    #Randomly initialized our parameters before running the algorithm
    W1 = np.random.randn(3,30)*0.01
    b1 = np.random.rand(3,1)
    W2 = np.random.randn(2,3)*0.01
    b2 = np.random.rand(2,1)
    W3 = np.random.rand(1,2)*0.01
    b3 = np.random.rand(1,1)
    dummy,m = X.shape
    
    caches = [] #we will store our cost at each iteration in this array
    count_vector = [] #We will store our iteration count in this array
    count = 0
    
    for i in range (1,iterations):
        
            count = count + 1
            
            count_vector.append(count)
        
            params = forward_prop(X,W1,W2,W3,b1,b2,b3) #forward propogation using our parameters
            
            #Define our values to be used in back propogation using the dictionary of values created from running forward_prop
            Z1 = params['Z1']
            Z2 = params['Z2']
            Z3 = params['Z3']
            A1 = params['A1']
            A2 = params['A2']
            A3 = params['A3']
            
            #Define our cost function, append the cost of each iteration to caches
            cost = -(1 / m)*np.sum(np.multiply(Y,np.log(A3)) + np.multiply((1-Y),np.log(1-A3)))
            caches.append(cost)
            
            #Backward propogation for layer 3
            dA3 = -Y/A3 + (1-Y)/(1-A3)
            dZ3 = dA3 * sigmoid(Z3)*(1-sigmoid(Z3))
            dW3 = (1 / m)*np.dot(dZ3,A2.T)
            db3 = (1 / m)*np.sum(dZ3,axis=1,keepdims=True)
            
            #Backward propogation for layer 2
            dA2 = np.dot(W3.T,dZ3)
            dZ2 = dA2*(1-np.power(tanh(Z2),2))
            dW2 = (1 / m)*np.dot(dZ2,A1.T)
            db2 = (1 / m)*np.sum(dZ2,axis=1,keepdims=True)
            
            #Backward propogation for layer 1
            dA1 = np.dot(W2.T,dZ2)
            dZ1 = dA1*(1-np.power(tanh(Z1),2))
            dW1 = (1 / m)*np.dot(dZ1,X.T)
            db1 = (1 / m)*np.sum(dZ1,axis=1,keepdims=True)
            
            #Redefine our weight parameters using the derivatives calculated in backward propogation
            W1 = W1 - alpha*dW1
            W2 = W2 - alpha*dW2
            W3 = W3 - alpha*dW3
            
            #Redefine our weight parameters using the derivatives calculated in backward propogation
            b1 = b1 - alpha*db1
            b2 = b2 - alpha*db2
            b3 = b3 - alpha*db3
        
    return W1,W2,W3,b1,b2,b3,count_vector,caches

# %%
#Lets see if our algorithm is working. We should see a declining learning curve with iteration, which eventually flatterns out
#This will help us determine the appropriate number of iterations to run to determine the appropriate parameters
#Note: we will use a learning rate of 0.5 for now

W1,W2,W3,b1,b2,b3,count,caches = gradient_descent(1000,X_test,Y_test,0.5)

plt.plot(count,caches,label='Cost')

plt.xlabel('Iteration')
plt.ylabel('Cost')

plt.title("Cost vs. Iteration")

plt.legend()

plt.show()

# %%
def predict(X,Y,iterations,alpha,X_train,Y_train):

    W1,W2,W3,b1,b2,b3,count,caches = gradient_descent(iterations,X_train,Y_train,alpha)
    
    Z1 = np.dot(W1,X)
    A1 = tanh(Z1 + b1)
    Z2 = np.dot(W2,A1)
    A2 = tanh(Z2 + b2)
    Z3 = np.dot(W3,A2)
    A3 = sigmoid(Z3 + b3)
    
    dummy,m = A3.shape
    Y_prediction = np.zeros((1, m))
    
    for i in range(m):
        
        Y_prediction[0, i] = 1 if A3[0, i] > 0.5 else 0
        
    return Y_prediction

# %%
#Lets see how accurate the predictions made by our neural network are compared to the training set and test set
print("Train accuracy: {:.3f} %".format(100 - np.mean(np.abs(predict(X_train,Y_train,1000,0.5,X_train,Y_train) - Y_train)) * 100))
print("Test accuracy: {:.3f} %".format(100 - np.mean(np.abs(predict(X_test,Y_test,1000,0.5,X_train,Y_train) - Y_test)) * 100))
# Out:
# Train accuracy: 98.947 %
# Test accuracy: 96.809 %

# %%
dummy,m1 = X_train.shape
dummy,m2 = X_test.shape

train_predict = predict(X_train,Y_train,1000,0.5,X_train,Y_train)
test_predict = predict(X_test,Y_test,1000,0.5,X_train,Y_train)
count_true_pos = 0
count_train_pos = 0

count_true_pos_test = 0
count_test_pos = 0

for i in range (1,m1):
    if train_predict[0,i] == 1 and Y_train[0,i] == 1:
        count_true_pos = count_true_pos + 1
    if Y_train[0,i] == 1:
        count_train_pos = count_train_pos + 1
        
for i in range (1,m2):
    if test_predict[0,i] == 1 and Y_test[0,i] == 1:
        count_true_pos_test = count_true_pos_test + 1
    if Y_test[0,i] == 1:
        count_test_pos = count_test_pos + 1
        
print(str(count_true_pos) + " positives predicted on the training set")
print(str(count_train_pos) + " true positives are in the training set")
print("The accuracy of true positives on the training set is: {:.3f} %".format(100-np.abs(100*((count_true_pos - count_train_pos)/count_train_pos))))
print("----------------------------------------------------------------")
print(str(count_true_pos_test) + " positives predicted on the test set")
print(str(count_test_pos) + " true positives are in the test set")
print("The accuracy of true positives on the test set is: {} %".format(100-np.abs(100*((count_true_pos_test - count_test_pos)/count_true_pos_test))))
# Out:
# 164 positives predicted on the training set
# 168 true positives are in the training set
# The accuracy of true positives on the training set is: 97.619 %
# ----------------------------------------------------------------
# 43 positives predicted on the test set
# 43 true positives are in the test set
# The accuracy of true positives on the test set is: 100.0 %

# %%
count_true_neg = 0
count_train_neg = 0

count_true_neg_test = 0
count_test_neg = 0

for i in range (1,m1):
    if train_predict[0,i] == 0 and Y_train[0,i] == 0:
        count_true_neg = count_true_neg + 1
    if Y_train[0,i] == 0:
        count_train_neg = count_train_neg + 1
        
for i in range (1,m2):
    if test_predict[0,i] == 0 and Y_test[0,i] == 0:
        count_true_neg_test = count_true_neg_test + 1
    if Y_test[0,i] == 0:
        count_test_neg = count_test_neg + 1
        
print(str(count_true_neg) + " negatives predicted on the training set")
print(str(count_train_neg) + " true negatives are in the training set")
print("The accuracy of true negatives on the training set is: {:.3f} %".format(100-np.abs(100*((count_true_neg - count_train_neg)/count_train_neg))))
print("----------------------------------------------------------------")
print(str(count_true_neg_test) + " negatives predicted on the test set")
print(str(count_test_neg) + " true negatives are in the test set")
print("The accuracy of true negatives on the test set is: {:.3f} %".format(100-np.abs(100*((count_true_neg_test - count_test_neg)/count_true_neg_test))))
# Out:
# 210 negatives predicted on the training set
# 211 true negatives are in the training set
# The accuracy of true negatives on the training set is: 99.526 %
# ----------------------------------------------------------------
# 138 negatives predicted on the test set
# 144 true negatives are in the test set
# The accuracy of true negatives on the test set is: 95.652 %
